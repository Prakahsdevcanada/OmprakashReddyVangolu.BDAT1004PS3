# %% [markdown]
# # Problem Set 3
# ---
# This problem set is based on lectures 9 and 10. For a complete list of topics please consult page 2 of the course syllabus. Please consult the “Instructions for Problem Set Submissions” document under course information before submitting your assignment.

# %% [markdown]
# # Question 1
# ```python
# Introduction:
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
# Occupations
# Step 1. Import the necessary libraries
# Step 2. Import the dataset from this address.
# Step 3. Assign it to a variable called users
# Step 4. Discover what is the mean age per occupation
# Step 5. Discover the Male ratio per occupation and sort it from the most to the least
# Step 6. For each occupation, calculate the minimum and maximum ages
# Step 7. For each combination of occupation and sex, calculate the mean age
# Step 8. For each occupation present the percentage of women and men
# ```

# %%
import pandas as pd

print("3")
users = pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user", sep= "|", engine = 'python')
# users1 = pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user", sep= "|")
# print(users)
print(type(users))
users
# Out:
# 3
# <class 'pandas.core.frame.DataFrame'>
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]

# %%
users.sort_values(by=['age','occupation'])
# Out:
#      user_id  age gender     occupation zip_code
# 29        30    7      M        student    55436
# 470      471   10      M        student    77459
# 288      289   11      M           none    94619
# 627      628   13      M           none    94306
# 141      142   13      M          other    48118
# ..       ...  ...    ...            ...      ...
# 584      585   69      M      librarian    98501
# 802      803   70      M  administrator    78212
# 766      767   70      M       engineer    00000
# 859      860   70      F        retired    48322
# 480      481   73      M        retired    37771
#
# [943 rows x 5 columns]

# %%
f = users[['user_id','age','gender']]
f
# Out:
#      user_id  age gender
# 0          1   24      M
# 1          2   53      F
# 2          3   23      M
# 3          4   24      M
# 4          5   33      F
# ..       ...  ...    ...
# 938      939   26      F
# 939      940   32      M
# 940      941   20      M
# 941      942   48      F
# 942      943   22      M
#
# [943 rows x 3 columns]

# %%
# print(users1)
print(users.index)
total_rows = users.age.value_counts()
print(total_rows)
# Out:
# RangeIndex(start=0, stop=943, step=1)
# 30    39
# 25    38
# 22    37
# 28    36
# 27    35
#       ..
# 7      1
# 66     1
# 11     1
# 10     1
# 73     1
# Name: age, Length: 61, dtype: int64

# %%
users.index
total_rows = users.count()
print(total_rows)
# Out:
# user_id       943
# age           943
# gender        943
# occupation    943
# zip_code      943
# dtype: int64

# %%
# Step 4. Discover what is the mean age per occupation
print("step4")

users.groupby('occupation')['age'].mean()
# Out:
# step4
# occupation
# administrator    38.746835
# artist           31.392857
# doctor           43.571429
# educator         42.010526
# engineer         36.388060
# entertainment    29.222222
# executive        38.718750
# healthcare       41.562500
# homemaker        32.571429
# lawyer           36.750000
# librarian        40.000000
# marketing        37.615385
# none             26.555556
# other            34.523810
# programmer       33.121212
# retired          63.071429
# salesman         35.666667
# scientist        35.548387
# student          22.081633
# technician       33.148148
# writer           36.311111
# Name: age, dtype: float64

# %%
users.head()
# Out:
#    user_id  age gender  occupation zip_code
# 0        1   24      M  technician    85711
# 1        2   53      F       other    94043
# 2        3   23      M      writer    32067
# 3        4   24      M  technician    43537
# 4        5   33      F       other    15213

# %%
# users[['occupation','age']]
usersd = users.groupby('occupation')['age'].mean()
type(usersd)
usersm = usersd.to_
# Out:
# pandas.core.series.Series

# %%
pd.sort

# %%
#
# users_m = users.groupby('occupation')['gender'].value_counts(normalize=True)*100
# import pdb
import pandas as pd
# pdb.set_trace()
# users_p = pd.DataFrame()
users = pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user", sep= "|")
users_m = users.groupby('occupation')['gender'].value_counts(normalize=True)

usersp = users_m.to_frame().rename(columns = {'gender':'ratios'}).reset_index()

userk = usersp[(usersp['gender'] == 'M') & True].reset_index()
userm = userk[['occupation','gender','ratios']]
userm.sort_values('ratios', ascending = False)
# Out:
#        occupation gender    ratios
# 2          doctor      M  1.000000
# 4        engineer      M  0.970149
# 19     technician      M  0.962963
# 15        retired      M  0.928571
# 14     programmer      M  0.909091
# 6       executive      M  0.906250
# 17      scientist      M  0.903226
# 5   entertainment      M  0.888889
# 9          lawyer      M  0.833333
# 16       salesman      M  0.750000
# 3        educator      M  0.726316
# 18        student      M  0.693878
# 13          other      M  0.657143
# 11      marketing      M  0.615385
# 20         writer      M  0.577778
# 12           none      M  0.555556
# 0   administrator      M  0.544304
# 1          artist      M  0.535714
# 10      librarian      M  0.431373
# 7      healthcare      M  0.312500
# 8       homemaker      M  0.142857

# %%
# Step 5. Discover the Male ratio per occupation and sort it from the most to the least
# users.groupby('occupation')['gender'].count().sort_values()
# users.groupby('occupation')["gender"].value_counts(normalize = True)*100
Male_users = users[users.gender == 'M']
Male_users.groupby('occupation')["gender"].value_counts()
# Male_users.groupby('occupation')["gender"].value_counts(normalize = True)*100
# Out:
# occupation     gender
# administrator  M          43
# artist         M          15
# doctor         M           7
# educator       M          69
# engineer       M          65
# entertainment  M          16
# executive      M          29
# healthcare     M           5
# homemaker      M           1
# lawyer         M          10
# librarian      M          22
# marketing      M          16
# none           M           5
# other          M          69
# programmer     M          60
# retired        M          13
# salesman       M           9
# scientist      M          28
# student        M         136
# technician     M          26
# writer         M          26
# Name: gender, dtype: int64

# %%
print()
print()
print("step6")
# my_max = users['occupation'].loc[users['age'].idxmax()]users['age']
my_max = users('occupation')['age'].idxmax()
print(my_max)
# Out:
# step6
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22200/2867824293.py in <module>
#       3 print("step6")
#       4 # my_max = users['occupation'].loc[users['age'].idxmax()]users['age']
# ----> 5 my_max = users('occupation')['age'].idxmax()
#       6 print(my_max)
#
# TypeError: 'DataFrame' object is not callable

# %%
#Step 6. For each occupation, calculate the minimum and maximum ages
users.head()
users.groupby('occupation').age.agg(['min', 'max']).reset_index()
# Out:
#        occupation  min  max
# 0   administrator   21   70
# 1          artist   19   48
# 2          doctor   28   64
# 3        educator   23   63
# 4        engineer   22   70
# 5   entertainment   15   50
# 6       executive   22   69
# 7      healthcare   22   62
# 8       homemaker   20   50
# 9          lawyer   21   53
# 10      librarian   23   69
# 11      marketing   24   55
# 12           none   11   55
# 13          other   13   64
# 14     programmer   20   63
# 15        retired   51   73
# 16       salesman   18   66
# 17      scientist   23   55
# 18        student    7   42
# 19     technician   21   55
# 20         writer   18   60

# %%
#Step 7. For each combination of occupation and sex, calculate the mean age
users.head()
users.groupby(['occupation','gender']).age.mean().reset_index()
# Out:
#        occupation gender        age
# 0   administrator      F  40.638889
# 1   administrator      M  37.162791
# 2          artist      F  30.307692
# 3          artist      M  32.333333
# 4          doctor      M  43.571429
# 5        educator      F  39.115385
# 6        educator      M  43.101449
# 7        engineer      F  29.500000
# 8        engineer      M  36.600000
# 9   entertainment      F  31.000000
# 10  entertainment      M  29.000000
# 11      executive      F  44.000000
# 12      executive      M  38.172414
# 13     healthcare      F  39.818182
# 14     healthcare      M  45.400000
# 15      homemaker      F  34.166667
# 16      homemaker      M  23.000000
# 17         lawyer      F  39.500000
# 18         lawyer      M  36.200000
# 19      librarian      F  40.000000
# 20      librarian      M  40.000000
# 21      marketing      F  37.200000
# 22      marketing      M  37.875000
# 23           none      F  36.500000
# 24           none      M  18.600000
# ...

# %%
#Step 8. For each occupation present the percentage of women and men
users.head()
usersm = users.groupby('occupation')['gender'].value_counts(normalize=True)*100
type(usersm)
# usersd = usersm.to_frame().rename(columns = {'gender':'percentage'})
usersd = usersm.to_frame().rename(columns = {'gender':'percentage'}).reset_index()
usersd
# Out:
#        occupation gender  percentage
# 0   administrator      M   54.430380
# 1   administrator      F   45.569620
# 2          artist      M   53.571429
# 3          artist      F   46.428571
# 4          doctor      M  100.000000
# 5        educator      M   72.631579
# 6        educator      F   27.368421
# 7        engineer      M   97.014925
# 8        engineer      F    2.985075
# 9   entertainment      M   88.888889
# 10  entertainment      F   11.111111
# 11      executive      M   90.625000
# 12      executive      F    9.375000
# 13     healthcare      F   68.750000
# 14     healthcare      M   31.250000
# 15      homemaker      F   85.714286
# 16      homemaker      M   14.285714
# 17         lawyer      M   83.333333
# 18         lawyer      F   16.666667
# 19      librarian      F   56.862745
# 20      librarian      M   43.137255
# 21      marketing      M   61.538462
# 22      marketing      F   38.461538
# 23           none      M   55.555556
# ...

# %% [markdown]
# # Question 2
# ```python
# Euro Teams
# Step 1. Import the necessary libraries
# Step 2. Import the dataset from this address
# Step 3. Assign it to a variable called euro12
# Step 4. Select only the Goal column
# Step 5. How many team participated in the Euro2012?
# Step 6. What is the number of columns in the dataset?
# Step 7. View only the columns Team, Yellow Cards and Red Cards and assign them to a dataframe called discipline
# Step 8. Sort the teams by Red Cards, then to Yellow Cards
# Step 9. Calculate the mean Yellow Cards given per Team
# Step 10. Filter teams that scored more than 6 goalsStep 11. Select the teams that start with G
# Step 12. Select the first 7 columns
# Step 13. Select all columns except the last 3
# Step 14. Present only the Shooting Accuracy from England, Italy and Russia
# ```

# %%
# Step 2. Import the dataset from this address
# Step 3. Assign it to a variable called euro12
import pandas as pd
euro12 = pd.read_csv("https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv")
euro12.head()
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
# 2         Denmark      4               10                10             50.0%
# 3         England      5               11                18             50.0%
# 4          France      3               22                24             37.9%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 0            16.0%                          32             0              0
# 1            12.9%                          39             0              0
# 2            20.0%                          27             1              0
# 3            17.2%                          40             0              0
# 4             6.5%                          65             1              0
#
# ...

# %%
# Step 4. Select only the Goal column

Goal = euro12[['Goals']]
Goal.head()
# Out:
#    Goals
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3

# %%
# Step 5. How many team participated in the Euro2012?
euro12.head()
euro12.Team.count()
# Out:
# 16

# %%
# Step 6. What is the number of columns in the dataset?
# euro12.info()
print(len(euro12.columns))
# Out:
# 35

# %%
# Step 7. View only the columns Team, Yellow Cards and Red Cards and assign them to a dataframe called discipline
euro12.head()
discipline = euro12[['Team','Yellow Cards','Red Cards']]
discipline
# Out:
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 6                Greece             9          1
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 9                Poland             7          1
# 10             Portugal            12          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %%
# Step 8. Sort the teams by Red Cards, then to Yellow Cards
euro12.head()
Team_RY = euro12[['Team','Red Cards','Yellow Cards']]
sort_TRY = Team_RY.sort_values(['Red Cards','Yellow Cards'])
sort_TRY
# Out:
#                    Team  Red Cards  Yellow Cards
# 2               Denmark          0             4
# 5               Germany          0             4
# 3               England          0             5
# 8           Netherlands          0             5
# 15              Ukraine          0             5
# 4                France          0             6
# 12               Russia          0             6
# 1        Czech Republic          0             7
# 14               Sweden          0             7
# 0               Croatia          0             9
# 13                Spain          0            11
# 10             Portugal          0            12
# 7                 Italy          0            16
# 11  Republic of Ireland          1             6
# 9                Poland          1             7
# 6                Greece          1             9

# %%
# Step 9. Calculate the mean Yellow Cards given per Team
euro12.head()
euro12.groupby('Team')['Yellow Cards'].mean().sort_values()
# type(euro12)
# Out:
# Team
# Denmark                 4.0
# Germany                 4.0
# England                 5.0
# Netherlands             5.0
# Ukraine                 5.0
# France                  6.0
# Republic of Ireland     6.0
# Russia                  6.0
# Czech Republic          7.0
# Poland                  7.0
# Sweden                  7.0
# Croatia                 9.0
# Greece                  9.0
# Spain                  11.0
# Portugal               12.0
# Italy                  16.0
# Name: Yellow Cards, dtype: float64

# %%
# Step 10. Filter teams that scored more than 6 goals
euro12.head()
euro12[(euro12.Goals > 6)]
# Out:
#        Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5   Germany     10               32                32             47.8%
# 13    Spain     12               42                33             55.9%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5             15.6%                          80             2              1
# 13            16.0%                         100             0              1
#
#     Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                      0  ...          10                 62.6%         63
# 13                     0  ...          15                 93.8%        102
#
#    Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5              49        12             4          0       15        15
# 13             83        19            11          0       17        17
#
#     Players Used
# 5             17
# 13            18
#
# ...

# %%
# Step 11. Select the teams that start with G
euro12.head()
series1 = euro12
series1.squeeze()
type(series1)
series2 = series1[(series1.Team.str.startswith('G'))]
series2
# Out:
#       Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5  Germany     10               32                32             47.8%
# 6   Greece      5                8                18             30.7%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5            15.6%                          80             2              1
# 6            19.2%                          32             1              1
#
#    Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                     0  ...          10                 62.6%         63
# 6                     1  ...          13                 65.1%         67
#
#   Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5             49        12             4          0       15        15
# 6             48        12             9          1       12        12
#
#    Players Used
# 5            17
# 6            20
#
# [2 rows x 35 columns]

# %%
#Step 12. Select the first 7 columns

import pandas as pd
euro12 = pd.read_csv("https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv")
euro12.head()
seven_columns = euro12.iloc[: , :7]
seven_columns.head()
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
# 2         Denmark      4               10                10             50.0%
# 3         England      5               11                18             50.0%
# 4          France      3               22                24             37.9%
#
#   % Goals-to-shots  Total shots (inc. Blocked)
# 0            16.0%                          32
# 1            12.9%                          39
# 2            20.0%                          27
# 3            17.2%                          40
# 4             6.5%                          65

# %%
#Step 13. Select all columns except the last 3
except_last_3 = euro12.iloc[: , :-3]
except_last_3.head()
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
# 2         Denmark      4               10                10             50.0%
# 3         England      5               11                18             50.0%
# 4          France      3               22                24             37.9%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 0            16.0%                          32             0              0
# 1            12.9%                          39             0              0
# 2            20.0%                          27             1              0
# 3            17.2%                          40             0              0
# 4             6.5%                          65             1              0
#
# ...

# %%
#Step 14. Present only the Shooting Accuracy from England, Italy and Russia
SA = euro12[['Team','Shooting Accuracy']]
SA.loc[SA['Team'].isin(['England', 'Italy', 'Russia'])]
# Out:
#        Team Shooting Accuracy
# 3   England             50.0%
# 7     Italy             43.0%
# 12   Russia             22.5%

# %% [markdown]
# # Question 3
# ```python
# Housing
# Step 1. Import the necessary libraries
# Step 2. Create 3 differents Series, each of length 100, as follows:
# • The first a random number from 1 to 4
# • The second a random number from 1 to 3
# • The third a random number from 10,000 to 30,000
# Step 3. Create a DataFrame by joinning the Series by column
# Step 4. Change the name of the columns to bedrs, bathrs, price_sqr_meter
# Step 5. Create a one column DataFrame with the values of the 3 Series and assign it
# to 'bigcolumn'
# Step 6. Ops it seems it is going only until index 99. Is it true?
# Step 7. Reindex the DataFrame so it goes from 0 to 299
# ```

# %%
#Step 1. Import the necessary libraries
# Step 2. Create 3 differents Series, each of length 100, as follows:
# • The first a random number from 1 to 4
# • The second a random number from 1 to 3
# • The third a random number from 10,000 to 30,000
# Step 3. Create a DataFrame by joinning the Series by column
import numpy as np
import pandas as pd
random_data = pd.Series(np.random.randint(1, 4, size=(100)).tolist())
random_data1 = pd.Series(np.random.randint(1, 3, size=(100)))
random_data2 = pd.Series(np.random.randint(10000, 30000, size=(100)))
df = pd.DataFrame(data = [random_data, random_data1,random_data2])
df = df.T
df1 = df.rename(columns = {0 : 'first', 1 : 'second', 2 : 'third'})
df1
# Out:
#     first  second  third
# 0       2       2  22589
# 1       3       1  11809
# 2       1       2  27831
# 3       1       1  27057
# 4       3       1  29019
# ..    ...     ...    ...
# 95      1       1  10315
# 96      2       2  15278
# 97      1       2  17201
# 98      2       2  26198
# 99      2       1  19264
#
# [100 rows x 3 columns]

# %%
# Step 4. Change the name of the columns to bedrs, bathrs, price_sqr_meter
df2 = df.rename(columns = {0 : 'bedrs', 1 : 'bathrs', 2 : 'price_sqr_meter'})
df2
# Out:
#     bedrs  bathrs  price_sqr_meter
# 0       2       2            22589
# 1       3       1            11809
# 2       1       2            27831
# 3       1       1            27057
# 4       3       1            29019
# ..    ...     ...              ...
# 95      1       1            10315
# 96      2       2            15278
# 97      1       2            17201
# 98      2       2            26198
# 99      2       1            19264
#
# [100 rows x 3 columns]

# %%
# Step 5. Create a one column DataFrame with the values of the 3 Series and assign it to 'bigcolumn'
# df1.head()
# # display(random_data)
# display(type(random_data))

# random_data = pd.Series((i[0] for i in random_data))
# random_data1 = pd.Series((i[0] for i in random_data1))
# random_data2 = pd.Series((i[0] for i in random_data2))


# # df1['bigcolumn'] = pd.concat([df1['first'],df1['second'],df1['third']], axis = 0)
# # bigcolumn = pd.concat([random_data,random_data1,random_data2], axis = 0)
# # df3 = df1['bigcolumn']
# # df3 = df3.to_frame()
# # df3
# display(type(bigcolumn))
# bigcolumn = bigcolumn.to_frame()
# print(type(bigcolumn))

# bigcolumn

bigcolumn = pd.DataFrame(pd.concat([random_data,random_data1,random_data2], names='A'))
# bigcolumn.reset_index(inplace = True, drop = True)
bigcolumn
# Out:
#         0
# 0       2
# 1       3
# 2       1
# 3       1
# 4       3
# ..    ...
# 95  10315
# 96  15278
# 97  17201
# 98  26198
# 99  19264
#
# [300 rows x 1 columns]

# %% [markdown]
# # Step 6. Ops it seems it is going only until index 99. Is it true?
# Ans1: There are hundred(100) rows in the DataFrame. But the index only shows till 99, as shown above. It is because the index starts with zero(0). Yes, it is true, the index is only going until 99.
#
# Ans: As for the bigcolumn the index goes all the way to 299 from 0. That means there are a total of 300 rows.

# %%
# Step 7. Reindex the DataFrame so it goes from 0 to 299
bigcolumn.reset_index(inplace = True, drop = True)
bigcolumn
# Out:
#          0
# 0        2
# 1        3
# 2        1
# 3        1
# 4        3
# ..     ...
# 295  10315
# 296  15278
# 297  17201
# 298  26198
# 299  19264
#
# [300 rows x 1 columns]

# %% [markdown]
# # Question 4
# ```python
# Wind Statistics
# The data have been modified to contain some missing values, identified by NaN.
# Using pandas should make this exercise easier, in particular for the bonus question.
# You should be able to perform all of these operations without using a for loop or
# other looping construct.
# The data in 'wind.data' has the following format:
# Yr Mo Dy RPT VAL ROS KIL SHA BIR DUB CLA MUL CLO BEL MAL
# 61 1 1 15.04 14.96 13.17 9.29 NaN 9.87 13.67 10.25 10.83 12.58 18.50 15.04
# 61 1 2 14.71 NaN 10.83 6.50 12.62 7.67 11.50 10.04 9.79 9.67 17.54 13.83
# 61 1 3 18.50 16.88 12.33 10.13 11.17 6.17 11.25 NaN 8.50 7.67 12.75 12.71
#
# The first three columns are year, month, and day. The remaining 12 columns are
# average windspeeds in knots at 12 locations in Ireland on that day.
# Step 1. Import the necessary libraries
# Step 2. Import the dataset from the attached file wind.txt
# Step 3. Assign it to a variable called data and replace the first 3 columns by a proper
# datetime index.
# Step 4. Year 2061? Do we really have data from this year? Create a function to fix it
# and apply it.
# Step 5. Set the right dates as the index. Pay attention at the data type, it should be
# datetime64[ns].
# Step 6. Compute how many values are missing for each location over the entire
# record.They should be ignored in all calculations below.
# Step 7. Compute how many non-missing values there are in total.
# Step 8. Calculate the mean windspeeds of the windspeeds over all the locations and
# all the times.
# A single number for the entire dataset.
# Step 9. Create a DataFrame called loc_stats and calculate the min, max and mean
# windspeeds and standard deviations of the windspeeds at each location over all the
# days
# A different set of numbers for each location.
# Step 10. Create a DataFrame called day_stats and calculate the min, max and mean
# windspeed and standard deviations of the windspeeds across all the locations at each
# day.
# A different set of numbers for each day.
# Step 11. Find the average windspeed in January for each location.
# Treat January 1961 and January 1962 both as January.
# Step 12. Downsample the record to a yearly frequency for each location.
# Step 13. Downsample the record to a monthly frequency for each location.
# Step 14. Downsample the record to a weekly frequency for each location.
# Step 15. Calculate the min, max and mean windspeeds and standard deviations of the
# windspeeds across all locations for each week (assume that the first week starts on
# January 2 1961) for the first 52 weeks.
# ```

# %%
import pandas as pd
import datetime
#Step 1. Import the necessary libraries
#Step 2. Import the dataset from the attached file wind.txt
#Step 3. Assign it to a variable called data and replace the first 3 columns by a proper datetime index.


# date = pd.read_csv("C:\Users\ompra\OneDrive\Desktop\1004_Data Programming\Assignments\problem set 3\wind.txt", sep = "\s+", parse_dates = [[0,1,2]])
data = pd.read_csv("wind.txt", sep = "\s+", parse_dates = {"Date" : ["Yr","Mo","Dy"]})
# data = data.rename(columns = {'Yr_Mo_Dy' : 'Date'})


# print(data.Date.unique())
# # data

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6574 entries, 0 to 6573
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    6574 non-null   datetime64[ns]
#  1   RPT     6568 non-null   float64
#  2   VAL     6571 non-null   float64
#  3   ROS     6572 non-null   float64
#  4   KIL     6569 non-null   float64
#  5   SHA     6572 non-null   float64
#  6   BIR     6574 non-null   float64
#  7   DUB     6571 non-null   float64
#  8   CLA     6572 non-null   float64
#  9   MUL     6571 non-null   float64
#  10  CLO     6573 non-null   float64
#  11  BEL     6574 non-null   float64
#  12  MAL     6570 non-null   float64
# dtypes: datetime64[ns](1), float64(12)
# memory usage: 667.8 KB

# %%
#Step 4. Year 2061? Do we really have data from this year? Create a function to fix it and apply it.

# def Date_fix(date):
#   year = date.year - 100 if date.year >= 1979 else date.year
#   return datetime.date(year, date.month, date.day)

# apply the function fix_century on the column and replace the values to the right ones
# data['Date'] = data['Date'].apply(Date_fix)

def updateDate(input):  
    if input.year > datetime.date.today().year:
        input = input + pd.DateOffset(years=-100)
    return input
data['date'] = data['Date'].apply(updateDate)
data.head()
data.info()

# data.info()
# display(data)
# display(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6574 entries, 0 to 6573
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    6574 non-null   datetime64[ns]
#  1   RPT     6568 non-null   float64
#  2   VAL     6571 non-null   float64
#  3   ROS     6572 non-null   float64
#  4   KIL     6569 non-null   float64
#  5   SHA     6572 non-null   float64
#  6   BIR     6574 non-null   float64
#  7   DUB     6571 non-null   float64
#  8   CLA     6572 non-null   float64
#  9   MUL     6571 non-null   float64
#  10  CLO     6573 non-null   float64
#  11  BEL     6574 non-null   float64
#  12  MAL     6570 non-null   float64
#  13  date    6574 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), float64(12)
# memory usage: 719.2 KB

# %%
#Step 5. Set the right dates as the index. Pay attention at the data type, it should be datetime64[ns].
# data = pd.read_csv("wind.txt", sep = "\s+", engine = 'python', parse_dates = [[0,1,2]])
# data = data.rename(columns = {'Yr_Mo_Dy' : 'Date'})

# def Date_fix(date):
#   year = date.year - 100 if date.year >= 1990 else date.year
#   return datetime.date(year, date.month, date.day)

# # apply the function fix_century on the column and replace the values to the right ones
# data['Date'] = data['Date'].apply(Date_fix)


# # data1 = data.reset_index().set_index('Date').reset_index()
# data1 = data.set_index('Date')
# # date = data.reset_index()
# # data1 = pd.to_datetime('Date')
# data1
# # type(data1)
# # data1.reset_index()
# data1.info()


data = data.set_index(['Date'])

data.info()
data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 6574 entries, 2061-01-01 to 1978-12-31
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RPT     6568 non-null   float64
#  1   VAL     6571 non-null   float64
#  2   ROS     6572 non-null   float64
#  3   KIL     6569 non-null   float64
#  4   SHA     6572 non-null   float64
#  5   BIR     6574 non-null   float64
#  6   DUB     6571 non-null   float64
#  7   CLA     6572 non-null   float64
#  8   MUL     6571 non-null   float64
#  9   CLO     6573 non-null   float64
#  10  BEL     6574 non-null   float64
#  11  MAL     6570 non-null   float64
#  12  date    6574 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(12)
# memory usage: 719.0 KB
#               RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# Date
# 2061-01-01  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# ...

# %%
# Step 6. Compute how many values are missing for each location over the entire record.
#They should be ignored in all calculations below.

# data2 = data1.reset_index()
# data2 = data2.drop(columns = 'index')
# display(data2.head())
# data2.info()
# display(data2.isnull().sum())
display(data.isna().sum())
data2 = pd.DataFrame()
data2= data.dropna()
# display(data2.isna().sum())

# data2 = data2.dropna()
# data2.head()
# Out:
# RPT     6
# VAL     3
# ROS     2
# KIL     5
# SHA     2
# BIR     0
# DUB     3
# CLA     2
# MUL     3
# CLO     1
# BEL     0
# MAL     4
# date    0
# dtype: int64

# %%
# Step 7. Compute how many non-missing values there are in total.
# data2 = data1.reset_index()
data2.notnull().sum().sum()
display(data2.notna().sum().sum())
# display(data1.notna().sum().sum())
# display(data2.notnull().sum().sum())
# display(data1.notnull().sum().sum())
# Out:
# 85098

# %%
#Step 8. Calculate the mean windspeeds of the windspeeds over all the locations and all the times.
#A single number for the entire dataset.
# data2 = data2.drop(columns = 'index')
# display(data2.head())
# data2.mean()

# # (data2.sum().sum())/(data2.sum().sum())
# display(data2.sum().sum())
# display(data2.notna().sum().sum())
# # data2.notna()
# display(data2.isnull().sum().sum())
# display(data2.notnull().sum().sum())
# display(data2.notnull().count().sum())
# display((data2.sum().sum())/(data2.notnull().sum().sum()))

# display((data2.sum().sum())/(data2.notna().count().sum()))

display(data2.mean().mean())
# Out:
# C:\Users\ompra\AppData\Local\Temp\ipykernel_19352\2649983354.py:18: FutureWarning:
#
# DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
# 10.222465245951712

# %%
# Step 9. Create a DataFrame called loc_stats and calculate the min, max and mean windspeeds and 
# standard deviations of the windspeeds at each location over all the days A different set of numbers for each location.

data2.head()
Loc_stats = data2.describe()
Loc_stats.head()
# Loc_stats.info()
# Out:
#                RPT          VAL          ROS          KIL          SHA  \
# count  6546.000000  6546.000000  6546.000000  6546.000000  6546.000000
# mean     12.359979    10.640267    11.656396     6.298587    10.448923
# std       5.618805     5.268695     5.007805     3.600942     4.933988
# min       0.670000     0.210000     1.500000     0.000000     0.130000
# 25%       8.120000     6.670000     7.970000     3.580000     6.750000
#
#                BIR          DUB          CLA          MUL          CLO  \
# count  6546.000000  6546.000000  6546.000000  6546.000000  6546.000000
# mean      7.085066     9.793006     8.486601     8.490257     8.696705
# std       3.967735     4.978030     4.498299     4.165947     4.500488
# min       0.000000     0.000000     0.000000     0.000000     0.040000
# 25%       4.000000     6.000000     5.090000     5.370000     5.330000
#
#                BEL          MAL
# count  6546.000000  6546.000000
# mean     13.110668    15.603129
# ...

# %%
# # Step 10. Create a DataFrame called day_stats and calculate the min, max and meanwindspeed and 
# # standard deviations of the windspeeds across all the locations at each day.
# # A different set of numbers for each day.

# day_stats = pd.DataFrame()

# data2.head()
# day_stats['min'] = data2.min(axis = 1)
# day_stats['max'] = data2.max(axis = 1)
# day_stats['mean'] = data2.mean(axis = 1)
# day_stats['std'] = data2.std(axis = 1)

# day_stats.head()


stats = data2.agg(['min', 'max', 'mean', 'std'])
display(stats.reset_index())
# Out:
#   index        RPT        VAL        ROS        KIL        SHA        BIR  \
# 0   min   0.670000   0.210000   1.500000   0.000000   0.130000   0.000000
# 1   max  35.800000  33.370000  33.840000  28.460000  37.540000  26.160000
# 2  mean  12.359979  10.640267  11.656396   6.298587  10.448923   7.085066
# 3   std   5.618805   5.268695   5.007805   3.600942   4.933988   3.967735
#
#          DUB        CLA        MUL        CLO        BEL        MAL  \
# 0   0.000000   0.000000   0.000000   0.040000   0.130000   0.670000
# 1  30.370000  31.080000  25.880000  28.210000  42.380000  42.540000
# 2   9.793006   8.486601   8.490257   8.696705  13.110668  15.603129
# 3   4.978030   4.498299   4.165947   4.500488   5.829054   6.702178
#
#                             date
# 0            1961-01-04 00:00:00
# 1            1978-12-31 00:00:00
# 2  1970-01-13 19:44:36.076993583
# 3   1890 days 22:36:35.393984640

# %%
# Step 11. Find the average windspeed in January for each location. Treat January 1961 and January 1962 both as January.
jan_mean = data2[data2.index.month==1].mean()
jan_mean
# Out:
# C:\Users\ompra\AppData\Local\Temp\ipykernel_19352\2062271423.py:2: FutureWarning:
#
# DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
# RPT    14.831609
# VAL    12.885389
# ROS    13.276275
# KIL     7.152477
# SHA    11.644467
# BIR     8.030561
# DUB    11.788336
# CLA     9.486962
# MUL     9.511501
# CLO    10.024069
# BEL    14.527848
# MAL    18.041826
# dtype: float64

# %%
# Step 12. Downsample the record to a yearly frequency for each location.
freq = data2.resample('Y').mean()
freq.head()
# Out:
#                   RPT        VAL        ROS       KIL        SHA       BIR  \
# Date
# 1972-12-31  12.463962  10.561311  12.058333  5.929699   9.430410  6.358825
# 1973-12-31  11.828466  10.680493  10.680493  5.547863   9.640877  6.548740
# 1974-12-31  13.643096  11.811781  12.336356  6.427041  11.110986  6.809781
# 1975-12-31  12.008575  10.293836  11.564712  5.269096   9.190082  5.668521
# 1976-12-31  11.737842  10.203115  10.761230  5.109426   8.846339  6.311038
#
#                   DUB       CLA       MUL       CLO        BEL        MAL
# Date
# 1972-12-31   9.704508  7.680792  8.357295  7.515273  12.727377  15.028716
# 1973-12-31   8.482110  7.614274  8.245534  7.812411  12.169699  15.441096
# 1974-12-31  10.084603  9.896986  9.331753  8.736356  13.252959  16.947671
# 1975-12-31   8.562603  7.843836  8.797945  7.382822  12.631671  15.307863
# 1976-12-31   9.149126  7.146202  8.883716  7.883087  12.332377  15.471448

# %%
# Step 13. Downsample the record to a monthly frequency for each location.
month_frequency = data2.resample('M').mean()
month_frequency.head()
# Out:
#                   RPT        VAL        ROS       KIL        SHA       BIR  \
# Date
# 1972-01-31  14.383871  11.848387  13.732258  5.925161  10.823226  7.291290
# 1972-02-29  14.046207  10.814483  12.960000  6.347586  10.918621  7.245172
# 1972-03-31  12.900000  10.505161  13.220323  6.949032  10.996452  6.949677
# 1972-04-30  13.675333  10.638000  13.237667  7.232667  11.253667  7.036333
# 1972-05-31  15.963226  12.636129  14.579355  7.974839  13.021290  7.560968
#
#                   DUB        CLA       MUL        CLO        BEL        MAL
# Date
# 1972-01-31  11.287097   6.733548  9.109355   8.728387  12.170645  17.598710
# 1972-02-29  10.276552   7.311379  8.710345   8.854483  13.124483  17.257931
# 1972-03-31   9.937742   7.025806  8.897742   7.835484  11.522581  15.282581
# 1972-04-30  11.350667   9.060333  9.842333   8.569000  12.967667  14.812000
# 1972-05-31  10.773226  10.083548  9.695806  10.083548  15.366452  16.471935

# %%
# Step 14. Downsample the record to a weekly frequency for each location.
week_frequency = data2.resample('W').mean()
week_frequency.head()
# Out:
#                   RPT        VAL        ROS       KIL        SHA       BIR  \
# Date
# 1972-01-02   9.125000   2.545000  13.270000  4.375000   4.980000  2.625000
# 1972-01-09  11.792857   7.761429  11.124286  4.212857   7.742857  5.500000
# 1972-01-16  17.061429  14.494286  16.241429  7.025714  12.231429  8.808571
# 1972-01-23  13.291429  13.375714  10.905714  5.304286  11.874286  8.457143
# 1972-01-30  15.732857  12.928571  16.025714  7.304286  11.665714  6.702857
#
#                   DUB       CLA        MUL        CLO        BEL        MAL
# Date
# 1972-01-02   9.520000  3.000000   6.915000   4.665000   5.230000  13.500000
# 1972-01-09   7.940000  4.924286   6.237143   6.247143   7.460000  13.962857
# 1972-01-16  12.767143  8.017143  10.114286  10.811429  13.950000  18.792857
# 1972-01-23  11.925714  7.724286  10.322857   9.744286  14.862857  19.944286
# 1972-01-30  12.847143  6.250000  10.048571   9.054286  13.215714  18.212857

# %%
# Step 15. Calculate the min, max and mean windspeeds and standard deviations of the
# windspeeds across all locations for each week (assume that the first week starts on
# January 2 1961) for the first 52 weeks.


Start_Date = pd.to_datetime('1961-01-02')
End_Date = start_date + pd.DateOffset(weeks=51)
week52_data = data2.loc[(data2.index>= Start_Date) & (data2.index<= End_Date)]
week52_data.resample('W').agg(['min', 'max','mean', 'std'])
# Out:
# C:\Users\ompra\AppData\Local\Temp\ipykernel_19352\1398373511.py:9: FutureWarning:
#
# ['date'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
# Empty DataFrame
# Columns: [(RPT, min), (RPT, max), (RPT, mean), (RPT, std), (VAL, min), (VAL, max), (VAL, mean), (VAL, std), (ROS, min), (ROS, max), (ROS, mean), (ROS, std), (KIL, min), (KIL, max), (KIL, mean), (KIL, std), (SHA, min), (SHA, max), (SHA, mean), (SHA, std), (BIR, min), (BIR, max), (BIR, mean), (BIR, std), (DUB, min), (DUB, max), (DUB, mean), (DUB, std), (CLA, min), (CLA, max), (CLA, mean), (CLA, std), (MUL, min), (MUL, max), (MUL, mean), (MUL, std), (CLO, min), (CLO, max), (CLO, mean), (CLO, std), (BEL, min), (BEL, max), (BEL, mean), (BEL, std), (MAL, min), (MAL, max), (MAL, mean), (MAL, std)]
# Index: []
#
# [0 rows x 48 columns]

# %% [markdown]
# # Question 5
# ```python
# Step 1. Import the necessary libraries
# Step 2. Import the dataset from this address.
# Step 3. Assign it to a variable called chipo.
# Step 4. See the first 10 entries
# Step 5. What is the number of observations in the dataset?
# Step 6. What is the number of columns in the dataset?
# Step 7. Print the name of all the columns.
# Step 8. How is the dataset indexed?
# Step 9. Which was the most-ordered item?
# Step 10. For the most-ordered item, how many items were ordered?
# Step 11. What was the most ordered item in the choice_description column?
# Step 12. How many items were orderd in total?
# Step 13.
# • Turn the item price into a float
# • Check the item price type
# • Create a lambda function and change the type of item price
# • Check the item price type
# Step 14. How much was the revenue for the period in the dataset?
# Step 15. How many orders were made in the period?
# Step 16. What is the average revenue amount per order?
# Step 17. How many different items are sold?
# ```

# %%
# Step 1. Import the necessary libraries
import pandas as pd

# %%
# Step 2. Import the dataset from this address.
# Step 3. Assign it to a variable called chipo.
# Step 4. See the first 10 entries

# data = pd.read_csv("wind.txt", sep = "\s+", engine = 'python', parse_dates = [[0,1,2]])
# users = pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user", sep= "|")


urltsv = "https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv"

chipo = pd.read_csv(urltsv, sep = "\t", engine = 'python')
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
# Step 5. What is the number of observations in the dataset?

display(chipo.shape)
display(chipo.info())


# The total number of observations in the dataset are 4622.
# Out:
# (4622, 5)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB
# None

# %%
# Step 6. What is the number of columns in the dataset?
display(chipo.shape)
chipo.head()

# The total number of Columns in the dataset are 5.
# Out:
# (4622, 5)
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
# Step 7. Print the name of all the columns.

chipo.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
# Step 8. How is the dataset indexed?

chipo.head()

#The dataset is indexed with the pandas indexing system.
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
# Step 9. Which was the most-ordered item?
# chipo['item_name'].value_counts()
# display(chipo.item_name.value_counts().sum())
# display(chipo.item_name.value_counts())
# display(chipo.quantity.sum())


# display(chipo['quantity'].value_counts())
# display(chipo[['item_name','quantity']].groupby(['item_name']).count().sort_values(by=['quantity'], ascending = False).sum())
# chipo.sort_values()


display(chipo.groupby('item_name')['quantity'].sum().sort_values(ascending = False).head(1))
# Out:
# item_name
# Chicken Bowl    761
# Name: quantity, dtype: int64

# %%
# Step 10. For the most-ordered item, how many items were ordered?

# chipo.head(5)
display(chipo.groupby('item_name')['quantity'].sum().sort_values(ascending = False).head(1))
# Out:
# item_name
# Chicken Bowl    761
# Name: quantity, dtype: int64

# %%
# Step 11. What was the most ordered item in the choice_description column?

display(chipo.head())

display(chipo.groupby('choice_description')['quantity'].sum().sort_values(ascending = False).head(1))
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# choice_description
# [Diet Coke]    159
# Name: quantity, dtype: int64

# %%
# Step 12. How many items were orderd in total?
display(chipo['quantity'].sum())
# Out:
# 4972

# %%
# Step 13.
# • Turn the item price into a float
# • Check the item price type
# • Create a lambda function and change the type of item price
# • Check the item price type

# display(type(chipo['item_price']))
# # chipo.info()
# print("")
# chipo1 = chipo
# chipo1['item_price'] = chipo1['item_price'].apply(lambda p: p.lstrip("$")).astype(float)
# # chipo1['item_price'] = chipo1['item_price'].apply(lambda p: p.lstrip("$"))
# display(type(chipo1['item_price']))


urltsv = "https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv"

chipo = pd.read_csv(urltsv, sep = "\t", engine = 'python')
chipo.head(10)

chipo1 = pd.DataFrame()
chipo1 = chipo
# type(chipo1['item_price'])
# chipo1.head(1)

print(type(chipo1['item_price']))
print(chipo1['item_price'].head(1))
chipo1['item_price'] = chipo1['item_price'].apply(lambda p: p.lstrip("$")).astype(float)
print(f'after changing type')
print(type(chipo1['item_price']))
chipo1['item_price'].head(1)
# Out:
# <class 'pandas.core.series.Series'>
# 0    $2.39
# Name: item_price, dtype: object
# after changing type
# <class 'pandas.core.series.Series'>
# 0    2.39
# Name: item_price, dtype: float64

# %%
# Step 14. How much was the revenue for the period in the dataset?

# display(chipo1.head())
# display(chipo1['quantity'].head(1))
chipo1['total_revenue'] = chipo1['quantity'] * chipo1['item_price']

chipo1.head()
chipo1['total_revenue'].sum()
# Out:
# 39237.02

# %%
# Step 15. How many orders were made in the period?


chipo.head()
# chipo['order_id'].value_counts()
chipo.order_id.nunique()
# Out:
# 1834

# %%
# Step 16. What is the average revenue amount per order?

display(chipo1.head())

chipo2 = chipo1.groupby('order_id').sum()
chipo2.head()
chipo2['average_per_order'] = chipo2['total_revenue'] / chipo2['quantity']
chipo2['average_per_order']
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description  item_price  \
# 0                                                NaN        2.39
# 1                                       [Clementine]        3.39
# 2                                            [Apple]        3.39
# 3                                                NaN        2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
#
#    total_revenue
# 0           2.39
# 1           3.39
# 2           3.39
# 3           2.39
# 4          33.96
# order_id
# 1        2.890000
# 2       16.980000
# 3        6.335000
# 4       10.500000
# ...

# %%
# Step 17. How many different items are sold?

chipo.head()

chipo['item_name'].nunique()
# Out:
# 50

# %% [markdown]
# # Question 6
# ```python
# Create a line plot showing the number of marriages and divorces per capita in the
# U.S. between 1867 and 2014. Label both lines and show the legend. Don't forget to label your axes!
# ```

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

relation = pd.read_csv(r"C:\Users\ompra\OneDrive\Desktop\1004_Data Programming\Assignments\problem set 3\us-marriages-divorces-1867-2014.csv")

# create figure and axis
fig, ax = plt.subplots()

# plot each column
marriage_capita = relation.loc[relation['Marriages_per_1000'].notna()]
divorce_capita = relation.loc[relation['Divorces_per_1000'].notna()]
ax.plot(marriage_capita['Year'], marriage_capita['Marriages_per_1000'])
ax.plot(divorce_capita['Year'], divorce_capita['Divorces_per_1000'])
plt.title('No. of Marriages-Divorces per capita annually')
plt.xlabel('Year')
plt.ylabel('No. of Marriages-Divorces per capita')
plt.legend(["Marriages per capita", "Divorces per capita"], loc=1, frameon=True)
plt.figure(figsize=(3, 10))
plt.show()

# %%
! pip install plotly
# Out:
# ...
#      --------------------------------------- 15.2/15.2 MB 18.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Question 7
# ```python
# Create a vertical bar chart comparing the number of marriages and divorces per
# capita in the U.S. between 1900, 1950, and 2000.
# Don't forget to label your axes!
# ```

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline


relation = pd.read_csv(r"C:\Users\ompra\OneDrive\Desktop\1004_Data Programming\Assignments\problem set 3\us-marriages-divorces-1867-2014.csv")





year_list = [1900, 1950, 2000]
relation_filter = relation.loc[relation['Year'].isin(year_list)]

X_axis = np.arange(relation_filter.shape[0])
width = 0.25    
b1 = plt.bar(X_axis, relation_filter['Marriages_per_1000'], 
        color = 'b', width = width, edgecolor = 'black', 
        label='Marriages per Capita')
b2 = plt.bar(X_axis+width, relation_filter['Divorces_per_1000'], 
        color = 'orange', width = width, edgecolor = 'black', 
        label='Divorces per Capita')
plt.xticks(X_axis + width/2,relation_filter['Year'])

for b in b1:
    yval = b.get_height()
    plt.text(b.get_x()+0.05, yval + .15, yval)
for b in b2:
    yval = b.get_height()
    plt.text(b.get_x()+0.05, yval + .15, yval)
plt.title('No. of Marriages-Divorces per capita')
plt.xlabel('Year')
plt.ylabel('No. of marriages and divorces per capita')
plt.legend()
plt.figure(figsize=(35, 15))
plt.show()

# %% [markdown]
# # Question 8
# ```python
# Create a horizontal bar chart that compares the deadliest actors in Hollywood. Sort
# the actors by their kill count and label each bar with the corresponding actor's name.
# Don't forget to label your axes!
# ```

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

relation = pd.read_csv(r"C:\Users\ompra\OneDrive\Desktop\1004_Data Programming\Assignments\problem set 3\actor_kill_counts.csv")
relation.head()

relation.plot.barh(x='Actor', y='Count')

plt.title("Number of Kills by Actor")
plt.ylabel('Actors')
plt.xlabel('Number of Kills')
plt.show()

# %% [markdown]
# # Question 9
# ```python
# Create a pie chart showing the fraction of all Roman Emperors that were
# assassinated.
# Make sure that the pie chart is an even circle, labels the categories, and shows the
# percentage breakdown of the categories.
# ```

# %%
import pandas as pd
import matplotlib.pyplot as plt

relation = pd.read_csv(r"C:\Users\ompra\OneDrive\Desktop\1004_Data Programming\Assignments\problem set 3\roman-emperor-reigns.csv")
# relation.head()
relation1  = relation.loc[relation['Cause_of_Death'].apply(lambda x: x.lower().find('assassinated')!=-1)]
fraction = relation1['Cause_of_Death'].count()/relation['Cause_of_Death'].count()
y = np.array([fraction, 1-fraction])

mylabels = ["Assassinated", "Not Assissinated"]
plt.pie(y, labels = mylabels, autopct='%.f', startangle = 90)
plt.legend(loc = 4)
plt.title('Percentage of all Roman Emperors that were assassinated')
plt.show()

# %% [markdown]
# # Question 10
# ```python
# Create a scatter plot showing the relationship between the total revenue earned by
# arcades and the number of Computer Science PhDs awarded in the U.S. between
# 2000 and 2009.
# Don't forget to label your axes!
# Color each dot according to its year.
# ```

# %%
import pandas as pd
import matplotlib.pyplot as plt

relation = pd.read_csv(r"C:\Users\ompra\OneDrive\Desktop\1004_Data Programming\Assignments\problem set 3\arcade-revenue-vs-cs-doctorates.csv")
# relation.head()


x = relation['Total Arcade Revenue (billions)']
y = relation['Computer Science Doctorates Awarded (US)']
colors = np.random.rand(relation.shape[0])
area = (30 * np.random.rand(relation.shape[0]))**2 
fig, axes = plt.subplots()
g = plt.scatter(x, y, s=area, c=colors, alpha=0.5)
axes.set_xlabel("Total Arcade Revenue (billions)")
axes.set_ylabel("Computer Science Doctorates Awarded (US)")
plt.title('Relationship between the total revenue earned by arcades and the number of Computer Science PhDs awards')
# ax.legend()
plt.show()
